# %% [markdown]
# Task:
# Creating a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of age or genders in a population

# %% [markdown]
# Step-1: Loading the dataset into the environment

# %%
import pandas as pd

data=pd.read_csv("dataset.csv")
data
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
data2=pd.read_csv("income data.csv")
data2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %% [markdown]
# Step-2: Cleaning the dataset

# %%
print(data.columns)
# as we have observed the Indicator name and Indicator code are same for every row. So we can remove them from our dataset
data=data.drop(['Indicator Name','Indicator Code'],axis=1)  #removing the unnecessary columns from the dataframe
print(data.columns) #cross-checking whether the columns have been deleted or not
#checking for the missing values in the dataset
print(data.isnull().sum()) # we can observe that there are some missing the years' columns
#getting the names of the columns which have null data
null_cols=data.columns[data.isnull().any()]
#converting into a list
null_cols_list=null_cols.to_list()
print(null_cols_list)

# checking whether all the columns contain numeric data or not because if we apply mean for non-numeric data then it will not be replaced and cause errors
numeric_columns=[col for col in null_cols_list if pd.api.types.is_numeric_dtype(data[col])]
print(numeric_columns)
# calculating the mean for numeric columns
data[numeric_columns]=data[numeric_columns].fillna(mean_values)
#cross checking if any null columns left
print(data.columns[data.isnull().any()].to_list())
# we can observe that no column is left with null values. So we can proceed with the visualization of the distribution
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
# ...

# %%
print(data2.columns)
# from the data2, we can observe that there is no need of special notes for our visualizations. So we can remove that column from the dataset
data2=data2.drop(['SpecialNotes'],axis=1)
print(data2.columns)
# also the table name is actually Country name, so we can change the column name into Country Name for better understanding
data2=data2.rename(columns={'TableName':'Country Name'})
print(data2.columns)

#checking for the missing values present in the dataset
print(data2.columns[data2.isnull().any()].to_list())
# we can observe that Region and IncomeGroup are null columns
# we can replace the null values with the previous value of the null value
# as we have 2 columns with null data. We can do it manually
data2['Region']=data2['Region'].fillna(method='ffill')
data2['IncomeGroup']=data2['IncomeGroup'].fillna(method='ffill')
# we can replace with a word NULL but actually in datasets, if the values are same as the previous then the next value will be left empty. So I chose this method of filling the previous values
# cross checking whether any column is still left with null values
print(data2.columns[data2.isnull().any()].to_list())
# we can see that there is no null value left in any column. So we can proceed with the visualizations
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName'], dtype='object')
# Index(['Country Code', 'Region', 'IncomeGroup', 'TableName'], dtype='object')
# Index(['Country Code', 'Region', 'IncomeGroup', 'Country Name'], dtype='object')
# ['Region', 'IncomeGroup']
# []
# C:\Users\saisa\AppData\Local\Temp\ipykernel_32120\1666273562.py:14: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\saisa\AppData\Local\Temp\ipykernel_32120\1666273562.py:15: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %% [markdown]
# Step-3: Visualizing the distribution

# %% [markdown]
# Visualizing the distribution of continuous variables in the dataset using a histogram.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 8
#       5 import seaborn as  sns
#       7 # reshaping the data into long format
# ----> 8 data_long=data.melt(id_vars=['Country'],var_name='Year',value_name='Population')
#       9 data_long['Year']=pd.to_numeric(data_long['Year'],errors='coerce')
#      10 fig=plx.line(data_long,x='Year',y='Population',color='Country',title='Population Trends by Country')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:9929, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9919 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9920 def melt(
#    9921     self,
#    (...)
#    9927     ignore_index: bool = True,
#    9928 ) -> DataFrame:
# ...
